# %%
import numpy as np
import pandas as pd

# %%
jr=pd.read_csv('D:\extrnal hard\ITI\Data visual\data_visual_project\data\Journalists Killings.csv')

# %%
journalists_killings=jr[jr['Country_killed']=='Israel and the Occupied Palestinian Territory']

# %%
journalists_killings.drop(columns=['Impunity_for_murder','Taken_captive','Threatened','Tortured','Nationality','Freelance','Country_killed','Type','Source_fire','Medium'],inplace=True)
# Out:
# c:\Users\abohassan\anaconda3\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
journalists_killings
# Out:
#                     Date                           Name   Sex  \
# 129      August 13, 2014                 Simone Camilli  Male
# 133        July 30, 2014                 Sameh al-Aryan  Male
# 134        July 30, 2014                     Rami Rayan  Male
# 135        July 20, 2014            Khaled Reyadh Hamad  Male
# 253    November 20, 2012                  Hussam Salama  Male
# 254    November 20, 2012                Mahmoud al-Kumi  Male
# 479      January 7, 2009            Basil Ibrahim Faraj  Male
# 516       April 16, 2008                    Fadel Shana  Male
# 566         May 13, 2007   Suleiman Abdul-Rahim al-Ashi  Male
# 744       March 22, 2004             Mohamed Abu Halima  Male
# 786          May 2, 2003                   James Miller  Male
# 789       April 19, 2003                 Nazih Darwazeh  Male
# 809   September 22, 2002                  Issam Tillawi  Male
# 811        July 12, 2002                 Imad Abu Zahra  Male
# ...

# %%
journalists_killings[['Sex']]=journalists_killings[['Sex']].fillna(value='Male')
# Out:
# c:\Users\abohassan\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
journalists_killings
# Out:
#                     Date                           Name   Sex  \
# 129      August 13, 2014                 Simone Camilli  Male
# 133        July 30, 2014                 Sameh al-Aryan  Male
# 134        July 30, 2014                     Rami Rayan  Male
# 135        July 20, 2014            Khaled Reyadh Hamad  Male
# 253    November 20, 2012                  Hussam Salama  Male
# 254    November 20, 2012                Mahmoud al-Kumi  Male
# 479      January 7, 2009            Basil Ibrahim Faraj  Male
# 516       April 16, 2008                    Fadel Shana  Male
# 566         May 13, 2007   Suleiman Abdul-Rahim al-Ashi  Male
# 744       March 22, 2004             Mohamed Abu Halima  Male
# 786          May 2, 2003                   James Miller  Male
# 789       April 19, 2003                 Nazih Darwazeh  Male
# 809   September 22, 2002                  Issam Tillawi  Male
# 811        July 12, 2002                 Imad Abu Zahra  Male
# ...

# %%
journalists_killings.fillna(value='Unknown',inplace=True)
# Out:
# c:\Users\abohassan\anaconda3\lib\site-packages\pandas\core\frame.py:5182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
journalists_killings
# Out:
#                     Date                           Name   Sex  \
# 129      August 13, 2014                 Simone Camilli  Male
# 133        July 30, 2014                 Sameh al-Aryan  Male
# 134        July 30, 2014                     Rami Rayan  Male
# 135        July 20, 2014            Khaled Reyadh Hamad  Male
# 253    November 20, 2012                  Hussam Salama  Male
# 254    November 20, 2012                Mahmoud al-Kumi  Male
# 479      January 7, 2009            Basil Ibrahim Faraj  Male
# 516       April 16, 2008                    Fadel Shana  Male
# 566         May 13, 2007   Suleiman Abdul-Rahim al-Ashi  Male
# 744       March 22, 2004             Mohamed Abu Halima  Male
# 786          May 2, 2003                   James Miller  Male
# 789       April 19, 2003                 Nazih Darwazeh  Male
# 809   September 22, 2002                  Issam Tillawi  Male
# 811        July 12, 2002                 Imad Abu Zahra  Male
# ...

# %%
journalists_killings['Date']=journalists_killings['Date'].astype('datetime64')
# Out:
# c:\Users\abohassan\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
journalists_killings=journalists_killings.reset_index(drop=True).sort_values(by=['Date'],ascending=False)

# %%
journalists_killings
# Out:
#          Date                           Name   Sex  \
# 0  2014-08-13                 Simone Camilli  Male
# 16 2014-08-13                  Ali Abu Afash  Male
# 2  2014-07-30                     Rami Rayan  Male
# 1  2014-07-30                 Sameh al-Aryan  Male
# 17 2014-07-30  Mohammed Nour al-Din al-Deiri  Male
# 3  2014-07-20            Khaled Reyadh Hamad  Male
# 18 2014-07-09                   Hamid Shihab  Male
# 4  2012-11-20                  Hussam Salama  Male
# 5  2012-11-20                Mahmoud al-Kumi  Male
# 6  2009-01-07            Basil Ibrahim Faraj  Male
# 7  2008-04-16                    Fadel Shana  Male
# 19 2007-05-14            Mohammad Matar Abdo  Male
# 8  2007-05-13   Suleiman Abdul-Rahim al-Ashi  Male
# 9  2004-03-22             Mohamed Abu Halima  Male
# 10 2003-05-02                   James Miller  Male
# 11 2003-04-19                 Nazih Darwazeh  Male
# 12 2002-09-22                  Issam Tillawi  Male
# ...

# %%
journalists_killings.to_csv('D:\\extrnal hard\\ITI\Data visual\\data_visual_project\\data\\Palestinians_journalists_killings.csv',index=False)
