# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### `first folder`

# %%
f1_0=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Israeli security forces\Gaza Strip.xlsx").drop(columns='Unnamed: 16')

# %%
f1_0["Killed By"]="Israeli security forces"

# %%
f1_0
# Out:
#                                             Name Date of event   Age  \
# 0     Muhammad Muhammad 'Abd al-Karim Abu 'Ammar    2021-09-30  39.0
# 1                    Ahmad Mustafa Mahmoud Saleh    2021-09-02  27.0
# 2                    'Omar Hassan Musa Abu a-Nil    2021-08-21  13.0
# 3                  Ousamah Khaled Muhammad D'eij    2021-08-21  31.0
# 4                  Huda Salah Rabi' al-Khazandar    2021-05-20  35.0
# ...                                          ...           ...   ...
# 7707               Sami Fathi Muhammad a-Taramsi    2000-10-01  17.0
# 7708             Muhammad Jamal Muhammad a-Durah    2000-09-30  11.0
# 7709                    Maher Rajab Yusef A'beid    2000-09-30  23.0
# 7710                Bassam Faiz Salim al-Balbisi    2000-09-30  47.0
# 7711  Muhammad Muhammad Badi'a Ibrahim al-'Atleh    2000-09-30  25.0
#
#       Citizenship     Event location Event location - District  \
# 0     Palestinian     al-Bureij R.C.             Deir al-Balah
# ...

# %%
f1_0.shape
# Out:
# (7712, 17)

# %%
f1_1=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Israeli security forces\West Bank.xlsx")

# %%
f1_1.head()
# Out:
#                                  Name Date of event   Age  Citizenship  \
# 0               Seif Hifzi Abu Libdah    2022-04-02  28.0  Palestinian
# 1      Saaeb Taysir Muhammad 'Abahreh    2022-04-02  34.0  Palestinian
# 2     Khalil Muhammad Khalil Tawalbah    2022-04-02  24.0  Palestinian
# 3         Ahmad Yunes Sidqi al-Atrash    2022-04-01  28.0  Palestinian
# 4  Sanad Muhammad Khalil Abu 'Atiyyah    2022-03-31  16.0  Palestinian
#
#   Event location Event location - District Event location - Region  \
# 0         'Araba                     Jenin               West Bank
# 1         'Araba                     Jenin               West Bank
# 2         'Araba                     Jenin               West Bank
# 3         Hebron                    Hebron               West Bank
# 4          Jenin                     Jenin               West Bank
#
#   Date of death Gender Took part in the hostilities Place of residence  \
# ...

# %%
f1_1.shape
# Out:
# (2351, 16)

# %%
f1_1["Killed By"]="Israeli security forces"

# %%
f1_1.head(2)
# Out:
#                              Name Date of event   Age  Citizenship  \
# 0           Seif Hifzi Abu Libdah    2022-04-02  28.0  Palestinian
# 1  Saaeb Taysir Muhammad 'Abahreh    2022-04-02  34.0  Palestinian
#
#   Event location Event location - District Event location - Region  \
# 0         'Araba                     Jenin               West Bank
# 1         'Araba                     Jenin               West Bank
#
#   Date of death Gender Took part in the hostilities Place of residence  \
# 0    2022-04-02      M               Not applicable     Nur Shams R.C.
# 1    2022-04-02      M               Not applicable         Jenin R.C.
#
#   Place of residence - District Type of injury       Ammunition  \
# 0                       Tulkarm        gunfire  live ammunition
# 1                         Jenin        gunfire  live ammunition
#
#                Affiliation Notes                Killed By
# 0  Israeli security forces   NaN  Israeli security forces
# ...

# %%
f1_2=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Israeli security forces\Occupied Territories.xlsx").drop(columns='Unnamed: 16')

# %%
f1_2
# Out:
#                                           Name Date of event   Age  \
# 0           Sanad Muhammad Khalil Abu 'Atiyyah    2022-03-31  16.0
# 1              Yazid Nidal Sa'ed a-Din a-S'adi    2022-03-31  24.0
# 2         'Alaa Muhammad 'Abd al-Qader Shahham    2022-03-15  20.0
# 3                    Nader Haitham Fathi Rayan    2022-03-15  16.0
# 4          'Abd a-Rahman Jamal Muhammad Qassem    2022-03-07  22.0
# ...                                        ...           ...   ...
# 9995              Hisham Ahmad Muhammad Muqbal    2000-10-07  27.0
# 9996  'Alaa Muhammad 'Abd a-Rahman al-Jawabrah    2000-10-06  14.0
# 9997                Majdi Samir Musa Masalmani    2000-10-06  15.0
# 9998            Wajed Musa Shihadah Abu 'Awwad    2000-10-06  22.0
# 9999            Rashad Isma'il Hussein a-Najar    2000-10-06  22.0
#
#       Citizenship        Event location Event location - District  \
# 0     Palestinian                 Jenin                     Jenin
# ...

# %%
f1_2["Killed By"]="Israeli security forces"

# %%
f1_2.head(2)
# Out:
#                                  Name Date of event   Age  Citizenship  \
# 0  Sanad Muhammad Khalil Abu 'Atiyyah    2022-03-31  16.0  Palestinian
# 1     Yazid Nidal Sa'ed a-Din a-S'adi    2022-03-31  24.0  Palestinian
#
#   Event location Event location - District Event location - Region  \
# 0          Jenin                     Jenin               West Bank
# 1          Jenin                     Jenin               West Bank
#
#   Date of death Gender Took part in the hostilities Place of residence  \
# 0    2022-03-31      M               Not applicable         Jenin R.C.
# 1    2022-03-31      M               Not applicable              Jenin
#
#   Place of residence - District Type of injury       Ammunition  \
# 0                         Jenin        gunfire  live ammunition
# 1                         Jenin        gunfire  live ammunition
#
#                Affiliation                                              Notes  \
# ...

# %%
f1_3=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Israeli security forces\Israel.xlsx")

# %%
f1_3.head(2)
# Out:
#                               Name Date of event   Age  Citizenship  \
# 0    Diyaa Ahmad Hussein Hamarshah    2022-03-29  26.0  Palestinian
# 1  Muhammad Hani Mus'ad Abu Mandil    2020-01-21  17.0  Palestinian
#
#             Event location Event location - District Event location - Region  \
# 0                Bnei Brak                    Israel                  Israel
# 1  Kissufim - Israeli side                    Israel                  Israel
#
#   Date of death Gender Took part in the hostilities Place of residence  \
# 0    2022-03-29      M               Not applicable             Ya'bad
# 1    2020-01-21      M                      Unknown    al-Maghazi R.C.
#
#   Place of residence - District Type of injury       Ammunition  \
# 0                         Jenin        gunfire  live ammunition
# 1                 Deir al-Balah        gunfire  live ammunition
#
#                Affiliation                                              Notes
# ...

# %%
f1_3["Killed By"]="Israeli security forces"

# %%
f1_3.head(2)
# Out:
#                               Name Date of event   Age  Citizenship  \
# 0    Diyaa Ahmad Hussein Hamarshah    2022-03-29  26.0  Palestinian
# 1  Muhammad Hani Mus'ad Abu Mandil    2020-01-21  17.0  Palestinian
#
#             Event location Event location - District Event location - Region  \
# 0                Bnei Brak                    Israel                  Israel
# 1  Kissufim - Israeli side                    Israel                  Israel
#
#   Date of death Gender Took part in the hostilities Place of residence  \
# 0    2022-03-29      M               Not applicable             Ya'bad
# 1    2020-01-21      M                      Unknown    al-Maghazi R.C.
#
#   Place of residence - District Type of injury       Ammunition  \
# 0                         Jenin        gunfire  live ammunition
# 1                 Deir al-Balah        gunfire  live ammunition
#
#                Affiliation                                              Notes  \
# ...

# %%
security_forces=pd.concat([f1_0,f1_1,f1_2,f1_3],axis=0,sort=True).reset_index(drop=True)

# %%
security_forces
# Out:
#                    Affiliation   Age       Ammunition  Citizenship  \
# 0      Israeli security forces  39.0  live ammunition  Palestinian
# 1      Israeli security forces  27.0  live ammunition  Palestinian
# 2      Israeli security forces  13.0  live ammunition  Palestinian
# 3      Israeli security forces  31.0  live ammunition  Palestinian
# 4      Israeli security forces  35.0          missile  Palestinian
# ...                        ...   ...              ...          ...
# 20177  Israeli security forces  37.0              NaN  Palestinian
# 20178  Israeli security forces  27.0              NaN  Palestinian
# 20179  Israeli security forces  30.0  live ammunition  Palestinian
# 20180  Israeli security forces  39.0  live ammunition  Palestinian
# 20181  Israeli security forces  19.0              NaN  Palestinian
#
#       Date of death Date of event   Event location Event location - District  \
# 0        2021-09-30    2021-09-30   al-Bureij R.C.             Deir al-Balah
# ...

# %%
security_forces.shape
# Out:
# (20182, 17)

# %%
security_forces.duplicated().sum()
# Out:
# 10007

# %%
security_forces.drop_duplicates(inplace=True)

# %%
security_forces.shape
# Out:
# (10175, 17)

# %%
security_forces.reset_index(drop=True,inplace=True)

# %%
security_forces.shape
# Out:
# (10175, 17)

# %% [markdown]
# ### `second folder`

# %%
f2_0=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Israeli civilians\Gaza Strip.xlsx")

# %%
f2_0
# Out:
#                             Name Date of event  Age  Citizenship  \
# 0  Tareq Suliman 'Abdallah Yasin    2005-07-24   22  Palestinian
# 1          Isma'il Brreis 'Ashur    2002-11-06   23  Palestinian
# 2                 Muhammad 'Awad    2002-03-10   21  Palestinian
# 3       Muhammad Judah Abu 'Aasi    2000-12-07   27  Palestinian
#
#            Event location Event location - District Event location - Region  \
# 0                Kissufim                Khan Yunis              Gaza Strip
# 1              Rafiah Yam                Gush Katif              Gaza Strip
# 2                Netzarim             Deir al-Balah              Gaza Strip
# 3  Erez (Industrial Zone)                North Gaza              Gaza Strip
#
#   Date of death Gender Took part in the hostilities Place of residence  \
# 0    2005-07-24      M                          Yes          Gaza city
# 1    2002-11-06      M                          Yes         Khan Yunis
# ...

# %%
f2_0.shape
# Out:
# (4, 16)

# %%
f2_0["Killed By"]="Israeli civilians"

# %%
f2_0.shape
# Out:
# (4, 17)

# %%
f2_1=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Israeli civilians\Israel.xlsx")

# %%
f2_1.shape
# Out:
# (7, 16)

# %%
f2_1["Killed By"]="Israeli civilians"

# %%
f2_2=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Israeli civilians\Occupied Territories.xlsx")

# %%
f2_2["Killed By"]="Israeli civilians"

# %%
f2_2.shape
# Out:
# (77, 17)

# %%
f2_3=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Israeli civilians\West Bank.xlsx")

# %%
f2_3.shape
# Out:
# (73, 16)

# %%
f2_3["Killed By"]="Israeli civilians"

# %%
f2_3.head(2)
# Out:
#                               Name Date of event   Age  Citizenship  \
# 0  Nidal Jum'ah 'Abdallah Ja'afrah    2022-03-31  30.0  Palestinian
# 1    Suliman 'Eid Yamin al-Hazalin    2022-01-05   NaN  Palestinian
#
#   Event location Event location - District Event location - Region  \
# 0    Neve Daniel                 Bethlehem               West Bank
# 1    Um al-Kheir                    Hebron               West Bank
#
#   Date of death Gender Took part in the hostilities Place of residence  \
# 0    2022-03-31      M               Not applicable           Tarqumya
# 1    2022-01-17      M               Not applicable        Um al-Kheir
#
#   Place of residence - District    Type of injury       Ammunition  \
# 0                        Hebron           gunfire  live ammunition
# 1                        Hebron  hit by a vehicle              NaN
#
#          Affiliation                                              Notes  \
# ...

# %%
Israeli_civilians=pd.concat([f2_0,f2_1,f2_2,f2_3],axis=0,sort=True).reset_index(drop=True)

# %%
Israeli_civilians.shape
# Out:
# (161, 17)

# %%
Palestinians_killed=pd.concat([security_forces,Israeli_civilians],axis=0,sort=True).reset_index(drop=True)

# %%
Palestinians_killed.drop(columns=["Affiliation"],inplace=True)

# %%
Palestinians_killed
# Out:
#         Age       Ammunition  Citizenship Date of death Date of event  \
# 0      39.0  live ammunition  Palestinian    2021-09-30    2021-09-30
# 1      27.0  live ammunition  Palestinian    2021-09-02    2021-09-02
# 2      13.0  live ammunition  Palestinian    2021-08-28    2021-08-21
# 3      31.0  live ammunition  Palestinian    2021-08-25    2021-08-21
# 4      35.0          missile  Palestinian    2021-05-20    2021-05-20
# ...     ...              ...          ...           ...           ...
# 10331  19.0              NaN  Palestinian    2000-12-22    2000-12-22
# 10332  18.0              NaN  Palestinian    2000-12-17    2000-12-17
# 10333  47.0              NaN  Palestinian    2000-11-14    2000-11-14
# 10334  28.0              NaN  Palestinian    2000-10-17    2000-10-17
# 10335  21.0              NaN  Palestinian    2000-10-07    2000-10-07
#
#        Event location Event location - District Event location - Region  \
# ...

# %%
Palestinians_killed['Event location - Region'].unique()
# Out:
# array(['Gaza Strip', 'West Bank', 'Israel', nan], dtype=object)

# %%
Palestinians_killed.isna().sum()
# Out:
# Age                                71
# Ammunition                       5253
# Citizenship                         2
# Date of death                       2
# Date of event                       2
# Event location                      2
# Event location - District           2
# Event location - Region             2
# Gender                             16
# Killed By                           0
# Name                                0
# Notes                             426
# Place of residence                 43
# Place of residence - District      43
# Took part in the hostilities        2
# Type of injury                    281
# dtype: int64

# %%
Palestinians_killed.drop(columns=["Ammunition"],inplace=True)

# %%
Palestinians_killed[(Palestinians_killed["Date of death"]!=Palestinians_killed["Date of event"])]
# Out:
#         Age  Citizenship Date of death Date of event    Event location  \
# 2      13.0  Palestinian    2021-08-28    2021-08-21         Gaza City
# 3      31.0  Palestinian    2021-08-25    2021-08-21         Gaza City
# 16     22.0  Palestinian    2021-05-24    2021-05-18          Khuza'ah
# 47     45.0  Palestinian    2021-06-03    2021-05-16         Gaza City
# 85     24.0  Palestinian    2021-06-03    2021-05-15         Gaza City
# ...     ...          ...           ...           ...               ...
# 10266   NaN          NaN           NaT           NaT               NaN
# 10272  30.0  Palestinian    2018-04-09    2018-04-08     Ma'ale Adumim
# 10288  32.0  Palestinian    2015-08-08    2015-07-31              Duma
# 10289  27.0  Palestinian    2015-09-07    2015-07-31              Duma
# 10322  40.0  Palestinian    2002-04-02    2002-04-01  Kochav Hashachar
#
#       Event location - District Event location - Region Gender  \
# ...

# %%
Palestinians_killed['Age'].mean()
# Out:
# 25.603896736483197

# %%
Palestinians_killed['Age']=Palestinians_killed['Age'].fillna(value=25)

# %%
Palestinians_killed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10336 entries, 0 to 10335
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            10336 non-null  float64
#  1   Citizenship                    10334 non-null  object
#  2   Date of death                  10334 non-null  datetime64[ns]
#  3   Date of event                  10334 non-null  datetime64[ns]
#  4   Event location                 10334 non-null  object
#  5   Event location - District      10334 non-null  object
#  6   Event location - Region        10334 non-null  object
#  7   Gender                         10320 non-null  object
#  8   Killed By                      10336 non-null  object
#  9   Name                           10336 non-null  object
#  10  Notes                          9910 non-null   object
#  11  Place of residence             10293 non-null  object
# ...

# %%
idx=(Palestinians_killed[Palestinians_killed['Date of death'].isnull()].index.tolist())

# %%
Palestinians_killed[Palestinians_killed['Date of death'].isnull()]
# Out:
#         Age Citizenship Date of death Date of event Event location  \
# 10189  25.0         NaN           NaT           NaT            NaN
# 10266  25.0         NaN           NaT           NaT            NaN
#
#       Event location - District Event location - Region Gender  \
# 10189                       NaN                     NaN    NaN
# 10266                       NaN                     NaN    NaN
#
#                Killed By                                               Name  \
# 10189  Israeli civilians  Fatally shot in the head and back by a settler...
# 10266  Israeli civilians  Fatally shot in the head and back by a settler...
#
#       Notes Place of residence Place of residence - District  \
# 10189   NaN                NaN                           NaN
# 10266   NaN                NaN                           NaN
#
#       Took part in the hostilities Type of injury
# 10189                          NaN            NaN
# ...

# %%
Palestinians_killed=Palestinians_killed.drop( idx,axis=0).reset_index(drop=True)

# %%
Palestinians_killed[Palestinians_killed['Date of death'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Citizenship, Date of death, Date of event, Event location, Event location - District, Event location - Region, Gender, Killed By, Name, Notes, Place of residence, Place of residence - District, Took part in the hostilities, Type of injury]
# Index: []

# %%
Palestinians_killed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10334 entries, 0 to 10333
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            10334 non-null  float64
#  1   Citizenship                    10334 non-null  object
#  2   Date of death                  10334 non-null  datetime64[ns]
#  3   Date of event                  10334 non-null  datetime64[ns]
#  4   Event location                 10334 non-null  object
#  5   Event location - District      10334 non-null  object
#  6   Event location - Region        10334 non-null  object
#  7   Gender                         10320 non-null  object
#  8   Killed By                      10334 non-null  object
#  9   Name                           10334 non-null  object
#  10  Notes                          9910 non-null   object
#  11  Place of residence             10293 non-null  object
# ...

# %%
Palestinians_killed[Palestinians_killed['Gender'].isnull()]
# Out:
#         Age  Citizenship Date of death Date of event          Event location  \
# 7159   25.0  Palestinian    2002-09-05    2002-09-05                Nissanit
# 7234   25.0  Palestinian    2002-05-07    2002-05-07                   Morag
# 7235   25.0  Palestinian    2002-05-05    2002-05-05                Kissufim
# 7236   25.0  Palestinian    2002-05-05    2002-05-05        Karni Checkpoint
# 7237   25.0  Palestinian    2002-05-03    2002-05-03              Gush Katif
# 7239   25.0  Palestinian    2002-05-01    2002-05-01                   Rafah
# 7254   25.0  Palestinian    2002-04-22    2002-04-22                   Dugit
# 7295   25.0  Palestinian    2002-03-18    2002-03-18                Kissufim
# 7333   25.0  Palestinian    2002-03-11    2002-03-11          al-Bureij R.C.
# 7431   25.0  Palestinian    2001-12-13    2001-12-13                Netzarim
# 9087   25.0  Palestinian    2002-10-07    2002-10-07       Baqah a-Sharqiyah
# ...

# %%
(Palestinians_killed["Gender"][Palestinians_killed["Gender"]=="M"]).count()
# Out:
# 9232

# %%
(Palestinians_killed["Gender"][Palestinians_killed["Gender"]=="F"]).count()
# Out:
# 1088

# %%
len(Palestinians_killed[Palestinians_killed['Gender'].isnull()].index.tolist())
# Out:
# 14

# %%
Palestinians_killed['Gender']=Palestinians_killed['Gender'].fillna(value="M")

# %%
Palestinians_killed[Palestinians_killed['Place of residence'].isnull()]
# Out:
#         Age  Citizenship Date of death Date of event          Event location  \
# 643    18.0  Palestinian    2015-10-09    2015-10-09               Gaza City
# 2158   35.0  Palestinian    2014-07-21    2014-07-21               Gaza City
# 2509   18.0  Palestinian    2014-07-19    2014-07-19           Deir al-Balah
# 2751   26.0  Palestinian    2014-07-10    2014-07-10                 Jabalya
# 3129   26.0  Palestinian    2011-10-29    2011-10-29               Gaza City
# 3153   14.0  Palestinian    2011-09-19    2011-08-19               Gaza City
# 5696   25.0  Palestinian    2006-07-26    2006-07-26                   Dugit
# 7159   25.0  Palestinian    2002-09-05    2002-09-05                Nissanit
# 7234   25.0  Palestinian    2002-05-07    2002-05-07                   Morag
# 7235   25.0  Palestinian    2002-05-05    2002-05-05                Kissufim
# 7236   25.0  Palestinian    2002-05-05    2002-05-05        Karni Checkpoint
# ...

# %%
Palestinians_killed['Place of residence']=Palestinians_killed['Place of residence'].fillna(value="Unknown")

# %%
Palestinians_killed['Place of residence - District']=Palestinians_killed['Place of residence - District'].fillna(value="Unknown")

# %%
Palestinians_killed['Notes']=Palestinians_killed['Notes'].fillna(value="There is no details")

# %%
Palestinians_killed[Palestinians_killed['Type of injury'].isnull()]
# Out:
#         Age  Citizenship Date of death Date of event      Event location  \
# 3328   16.0  Palestinian    2009-01-18    2009-01-18           Gaza City
# 3330   60.0  Palestinian    2009-01-18    2009-01-18         Beit Lahiya
# 3333   62.0  Palestinian    2009-01-18    2009-01-18         Beit Lahiya
# 3334   17.0  Palestinian    2009-01-18    2009-01-18         Beit Lahiya
# 3335   82.0  Palestinian    2009-01-18    2009-01-18           Gaza City
# ...     ...          ...           ...           ...                 ...
# 9515   40.0  Palestinian    2002-03-09    2002-03-07             Tulkarm
# 9516   36.0  Palestinian    2002-03-09    2002-03-07             Tulkarm
# 10125  21.0  Palestinian    2003-06-26    2003-06-26  Baqah al-Gharbiyah
# 10126  18.0  Palestinian    2003-06-26    2003-06-26  Baqah al-Gharbiyah
# 10182  16.0  Palestinian    2014-07-03    2014-07-03           Jerusalem
#
#       Event location - District Event location - Region Gender  \
# ...

# %%
Palestinians_killed['Type of injury']=Palestinians_killed['Type of injury'].fillna(value="Unknown")

# %%
Palestinians_killed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10334 entries, 0 to 10333
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            10334 non-null  float64
#  1   Citizenship                    10334 non-null  object
#  2   Date of death                  10334 non-null  datetime64[ns]
#  3   Date of event                  10334 non-null  datetime64[ns]
#  4   Event location                 10334 non-null  object
#  5   Event location - District      10334 non-null  object
#  6   Event location - Region        10334 non-null  object
#  7   Gender                         10334 non-null  object
#  8   Killed By                      10334 non-null  object
#  9   Name                           10334 non-null  object
#  10  Notes                          10334 non-null  object
#  11  Place of residence             10334 non-null  object
# ...

# %%
Palestinians_killed.reset_index(drop=True,inplace=True)

# %%
Palestinians_killed.head()
# Out:
#     Age  Citizenship Date of death Date of event  Event location  \
# 0  39.0  Palestinian    2021-09-30    2021-09-30  al-Bureij R.C.
# 1  27.0  Palestinian    2021-09-02    2021-09-02    Jabalya R.C.
# 2  13.0  Palestinian    2021-08-28    2021-08-21       Gaza City
# 3  31.0  Palestinian    2021-08-25    2021-08-21       Gaza City
# 4  35.0  Palestinian    2021-05-20    2021-05-20      Khan Yunis
#
#   Event location - District Event location - Region Gender  \
# 0             Deir al-Balah              Gaza Strip      M
# 1                North Gaza              Gaza Strip      M
# 2                      Gaza              Gaza Strip      M
# 3                      Gaza              Gaza Strip      M
# 4                Khan Yunis              Gaza Strip      F
#
#                  Killed By                                        Name  \
# 0  Israeli security forces  Muhammad Muhammad 'Abd al-Karim Abu 'Ammar
# 1  Israeli security forces                 Ahmad Mustafa Mahmoud Saleh
# ...

# %% [markdown]
# ### `3rd folder`

# %%
f3_0=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Unknown Israeli party\West Bank.xlsx")

# %%
f3_0.shape
# Out:
# (9, 16)

# %%
f3_0["Killed By"]="Israeli party"

# %%
f3_0
# Out:
#                                  Name Date of event  Age  Citizenship  \
# 0        'Omar Ibrahim Ayub Abu 'Asab    2021-11-17   16  Palestinian
# 1              'Awad Ahmad 'Awad Harb    2021-05-14   27  Palestinian
# 2          Nidal Sayel Mustafa Safadi    2021-05-14   30  Palestinian
# 3  Isma'il Jamal 'Abd al-Majid Tubasi    2021-05-14   26  Palestinian
# 4           Nimer Mahmoud Ahmad Jamal    2017-09-26   37  Palestinian
# 5      Muhammad Mahmoud Dawood Sharaf    2017-07-21   18  Palestinian
# 6         Fadi Ahmad Hamdan al-Qunbar    2017-01-08   28  Palestinian
# 7          Ahmad Hamadah Yunes Qneibi    2015-10-30   23  Palestinian
# 8             Milad Sa'id 'Ali 'Ayash    2011-05-13   17  Palestinian
#
#          Event location Event location - District Event location - Region  \
# 0  Old City (Jerusalem)            East Jerusalem               West Bank
# 1                Iskaka                    Salfit               West Bank
# ...

# %%
f3_0.drop(columns=['Affiliation','Ammunition'],inplace=True)

# %%
f3_0
# Out:
#                                  Name Date of event  Age  Citizenship  \
# 0        'Omar Ibrahim Ayub Abu 'Asab    2021-11-17   16  Palestinian
# 1              'Awad Ahmad 'Awad Harb    2021-05-14   27  Palestinian
# 2          Nidal Sayel Mustafa Safadi    2021-05-14   30  Palestinian
# 3  Isma'il Jamal 'Abd al-Majid Tubasi    2021-05-14   26  Palestinian
# 4           Nimer Mahmoud Ahmad Jamal    2017-09-26   37  Palestinian
# 5      Muhammad Mahmoud Dawood Sharaf    2017-07-21   18  Palestinian
# 6         Fadi Ahmad Hamdan al-Qunbar    2017-01-08   28  Palestinian
# 7          Ahmad Hamadah Yunes Qneibi    2015-10-30   23  Palestinian
# 8             Milad Sa'id 'Ali 'Ayash    2011-05-13   17  Palestinian
#
#          Event location Event location - District Event location - Region  \
# 0  Old City (Jerusalem)            East Jerusalem               West Bank
# 1                Iskaka                    Salfit               West Bank
# ...

# %%
f3_1=pd.read_excel("D:\extrnal hard\ITI\Data visual\data_visual_project\data\Fatalities\Palestinians killed by Unknown Israeli party\Israel.xlsx")

# %%
f3_1
# Out:
#                                            Name Date of event  Age  \
# 0  'Abd al-Muhsen Shaher 'Abd al-Muhsen Hasunah    2015-12-14   21
# 1                Mar'i Ahmad Mahmoud a-Radaydeh    2009-03-05   25
#
#    Citizenship Event location Event location - District  \
# 0  Palestinian      Jerusalem                    Israel
# 1  Palestinian      Jerusalem                    Israel
#
#   Event location - Region Date of death Gender Took part in the hostilities  \
# 0                  Israel    2015-12-14      M               Not applicable
# 1                  Israel    2009-03-05      M                          NaN
#
#      Place of residence Place of residence - District Type of injury  \
# 0                Hebron                        Hebron        gunfire
# 1  Beit Hanina al-Balad                       al-Quds        gunfire
#
#         Ammunition            Affiliation  \
# 0  live ammunition  unknown Israeli party
# 1  live ammunition  unknown Israeli party
#
# ...

# %%
f3_1.drop(columns=['Affiliation','Ammunition'],inplace=True)

# %%
f3_1["Killed By"]="Israeli party"

# %%
f3_1.shape
# Out:
# (2, 15)

# %%
party=pd.concat([f3_0,f3_1],axis=0,sort=True).reset_index(drop=True)

# %%
party
# Out:
#     Age  Citizenship Date of death Date of event        Event location  \
# 0    16  Palestinian    2021-11-17    2021-11-17  Old City (Jerusalem)
# 1    27  Palestinian    2021-05-14    2021-05-14                Iskaka
# 2    30  Palestinian    2021-05-14    2021-05-14                 'Urif
# 3    26  Palestinian    2021-05-14    2021-05-14              a-Rihiya
# 4    37  Palestinian    2017-09-26    2017-09-26              Har Adar
# 5    18  Palestinian    2017-07-21    2017-07-21          Ras al-'Amud
# 6    28  Palestinian    2017-01-08    2017-01-08        East Jerusalem
# 7    23  Palestinian    2015-10-30    2015-10-30         Sheikh Jarrah
# 8    17  Palestinian    2011-05-14    2011-05-13                Silwan
# 9    21  Palestinian    2015-12-14    2015-12-14             Jerusalem
# 10   25  Palestinian    2009-03-05    2009-03-05             Jerusalem
#
#    Event location - District Event location - Region Gender      Killed By  \
# ...

# %%
party['Took part in the hostilities']=party['Took part in the hostilities'].fillna(value="Not applicable")

# %% [markdown]
# ### `all folders in one `

# %%
Palestinians_killed.shape
# Out:
# (10334, 15)

# %%
Palestinians_killed=pd.concat([Palestinians_killed,party],axis=0,sort=True).reset_index(drop=True)

# %%
Palestinians_killed.shape
# Out:
# (10345, 15)

# %%
Palestinians_killed
# Out:
#         Age  Citizenship Date of death Date of event  Event location  \
# 0      39.0  Palestinian    2021-09-30    2021-09-30  al-Bureij R.C.
# 1      27.0  Palestinian    2021-09-02    2021-09-02    Jabalya R.C.
# 2      13.0  Palestinian    2021-08-28    2021-08-21       Gaza City
# 3      31.0  Palestinian    2021-08-25    2021-08-21       Gaza City
# 4      35.0  Palestinian    2021-05-20    2021-05-20      Khan Yunis
# ...     ...          ...           ...           ...             ...
# 10340  28.0  Palestinian    2017-01-08    2017-01-08  East Jerusalem
# 10341  23.0  Palestinian    2015-10-30    2015-10-30   Sheikh Jarrah
# 10342  17.0  Palestinian    2011-05-14    2011-05-13          Silwan
# 10343  21.0  Palestinian    2015-12-14    2015-12-14       Jerusalem
# 10344  25.0  Palestinian    2009-03-05    2009-03-05       Jerusalem
#
#       Event location - District Event location - Region Gender  \
# 0                 Deir al-Balah              Gaza Strip      M
# ...

# %%
Palestinians_killed
# Out:
#         Age  Citizenship Date of death Date of event  Event location  \
# 0      39.0  Palestinian    2021-09-30    2021-09-30  al-Bureij R.C.
# 1      27.0  Palestinian    2021-09-02    2021-09-02    Jabalya R.C.
# 2      13.0  Palestinian    2021-08-28    2021-08-21       Gaza City
# 3      31.0  Palestinian    2021-08-25    2021-08-21       Gaza City
# 4      35.0  Palestinian    2021-05-20    2021-05-20      Khan Yunis
# ...     ...          ...           ...           ...             ...
# 10340  28.0  Palestinian    2017-01-08    2017-01-08  East Jerusalem
# 10341  23.0  Palestinian    2015-10-30    2015-10-30   Sheikh Jarrah
# 10342  17.0  Palestinian    2011-05-14    2011-05-13          Silwan
# 10343  21.0  Palestinian    2015-12-14    2015-12-14       Jerusalem
# 10344  25.0  Palestinian    2009-03-05    2009-03-05       Jerusalem
#
#       Event location - District Event location - Region Gender  \
# 0                 Deir al-Balah              Gaza Strip      M
# ...

# %%
Palestinians_killed["Count"]=1

# %%
Palestinians_killed
# Out:
#         Age  Citizenship Date of death Date of event  Event location  \
# 0      39.0  Palestinian    2021-09-30    2021-09-30  al-Bureij R.C.
# 1      27.0  Palestinian    2021-09-02    2021-09-02    Jabalya R.C.
# 2      13.0  Palestinian    2021-08-28    2021-08-21       Gaza City
# 3      31.0  Palestinian    2021-08-25    2021-08-21       Gaza City
# 4      35.0  Palestinian    2021-05-20    2021-05-20      Khan Yunis
# ...     ...          ...           ...           ...             ...
# 10340  28.0  Palestinian    2017-01-08    2017-01-08  East Jerusalem
# 10341  23.0  Palestinian    2015-10-30    2015-10-30   Sheikh Jarrah
# 10342  17.0  Palestinian    2011-05-14    2011-05-13          Silwan
# 10343  21.0  Palestinian    2015-12-14    2015-12-14       Jerusalem
# 10344  25.0  Palestinian    2009-03-05    2009-03-05       Jerusalem
#
#       Event location - District Event location - Region Gender  \
# 0                 Deir al-Balah              Gaza Strip      M
# ...

# %%
Palestinians_killed.describe()
# Out:
#                 Age    Count
# count  10345.000000  10345.0
# mean      25.598550      1.0
# std       12.766274      0.0
# min        0.000000      1.0
# 25%       18.000000      1.0
# 50%       23.000000      1.0
# 75%       30.000000      1.0
# max      112.000000      1.0

# %%
Palestinians_killed[Palestinians_killed["Date of death"]!=Palestinians_killed["Date of event"]]
# Out:
#         Age  Citizenship Date of death Date of event    Event location  \
# 2      13.0  Palestinian    2021-08-28    2021-08-21         Gaza City
# 3      31.0  Palestinian    2021-08-25    2021-08-21         Gaza City
# 16     22.0  Palestinian    2021-05-24    2021-05-18          Khuza'ah
# 47     45.0  Palestinian    2021-06-03    2021-05-16         Gaza City
# 85     24.0  Palestinian    2021-06-03    2021-05-15         Gaza City
# ...     ...          ...           ...           ...               ...
# 10270  30.0  Palestinian    2018-04-09    2018-04-08     Ma'ale Adumim
# 10286  32.0  Palestinian    2015-08-08    2015-07-31              Duma
# 10287  27.0  Palestinian    2015-09-07    2015-07-31              Duma
# 10320  40.0  Palestinian    2002-04-02    2002-04-01  Kochav Hashachar
# 10342  17.0  Palestinian    2011-05-14    2011-05-13            Silwan
#
#       Event location - District Event location - Region Gender  \
# ...

# %%
Palestinians_killed.drop(columns=['Date of death'],inplace=True)

# %%
Palestinians_killed.shape
# Out:
# (10345, 15)

# %%
Palestinians_killed=Palestinians_killed.sort_values(by=['Date of event'],ascending=False).reset_index(drop=True)

# %%
Palestinians_killed
# Out:
#         Age  Citizenship Date of event  Event location  \
# 0      28.0  Palestinian    2022-04-02          'Araba
# 1      34.0  Palestinian    2022-04-02          'Araba
# 2      24.0  Palestinian    2022-04-02          'Araba
# 3      28.0  Palestinian    2022-04-01          Hebron
# 4      24.0  Palestinian    2022-03-31           Jenin
# ...     ...          ...           ...             ...
# 10340  18.0  Palestinian    2000-09-29  East Jerusalem
# 10341  45.0  Palestinian    2000-09-29  East Jerusalem
# 10342  22.0  Palestinian    2000-09-29  East Jerusalem
# 10343  25.0  Palestinian    2000-09-29  East Jerusalem
# 10344  35.0  Palestinian    2000-09-29  East Jerusalem
#
#       Event location - District Event location - Region Gender  \
# 0                         Jenin               West Bank      M
# 1                         Jenin               West Bank      M
# 2                         Jenin               West Bank      M
# ...

# %%
Palestinians_killed['Citizenship'].unique()
# Out:
# array(['Palestinian', 'American', 'Jordanian', 'Israeli'], dtype=object)

# %%
Palestinians_killed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10345 entries, 0 to 10344
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            10345 non-null  float64
#  1   Citizenship                    10345 non-null  object
#  2   Date of event                  10345 non-null  datetime64[ns]
#  3   Event location                 10345 non-null  object
#  4   Event location - District      10345 non-null  object
#  5   Event location - Region        10345 non-null  object
#  6   Gender                         10345 non-null  object
#  7   Killed By                      10345 non-null  object
#  8   Name                           10345 non-null  object
#  9   Notes                          10345 non-null  object
#  10  Place of residence             10345 non-null  object
#  11  Place of residence - District  10345 non-null  object
# ...

# %%
Palestinians_killed[Palestinians_killed['Citizenship']=='Israeli']
# Out:
#        Age Citizenship Date of event Event location Event location - District  \
# 5440  31.0     Israeli    2008-07-02      Jerusalem                    Israel
#
#      Event location - Region Gender                Killed By  \
# 5440                  Israel      M  Israeli security forces
#
#                      Name                                              Notes  \
# 5440  Husam Taysir Dwayat  Shot after he ran over and crushed three drive...
#
#      Place of residence Place of residence - District  \
# 5440          Zur Baher                East Jerusalem
#
#      Took part in the hostilities Type of injury  Count
# 5440                          Yes        gunfire      1

# %%
Palestinians_killed.to_csv('D:\extrnal hard\ITI\Data visual\data_visual_project\data\Palestinians_killed_fulldate.csv',index=False)

# %%
Palestinians_killed['Year'] = pd.to_datetime(Palestinians_killed['Date of event']).dt.year
Palestinians_killed['Month'] = pd.to_datetime(Palestinians_killed['Date of event']).dt.month
Palestinians_killed['Day'] = pd.to_datetime(Palestinians_killed['Date of event']).dt.day

# %%
Palestinians_killed.drop(columns=['Date of event'],inplace=True)

# %%
Palestinians_killed
# Out:
#         Age  Citizenship  Event location Event location - District  \
# 0      28.0  Palestinian          'Araba                     Jenin
# 1      24.0  Palestinian          'Araba                     Jenin
# 2      34.0  Palestinian          'Araba                     Jenin
# 3      28.0  Palestinian          Hebron                    Hebron
# 4      30.0  Palestinian     Neve Daniel                 Bethlehem
# ...     ...          ...             ...                       ...
# 10340  18.0  Palestinian  East Jerusalem            East Jerusalem
# 10341  45.0  Palestinian  East Jerusalem            East Jerusalem
# 10342  22.0  Palestinian  East Jerusalem            East Jerusalem
# 10343  25.0  Palestinian  East Jerusalem            East Jerusalem
# 10344  35.0  Palestinian  East Jerusalem            East Jerusalem
#
#       Event location - Region Gender                Killed By  \
# 0                   West Bank      M  Israeli security forces
# ...

# %%
months= {1:"January",2:"February",3:"March ",4:"April",5:"May",6:"June ",7:"July",8:"August",9:"September",10:"October",11:"November",12:"December"}

# %%
Palestinians_killed[["Month"]]=Palestinians_killed[["Month"]].replace(months)

# %%
Palestinians_killed
# Out:
#         Age  Citizenship  Event location Event location - District  \
# 0      28.0  Palestinian          'Araba                     Jenin
# 1      24.0  Palestinian          'Araba                     Jenin
# 2      34.0  Palestinian          'Araba                     Jenin
# 3      28.0  Palestinian          Hebron                    Hebron
# 4      30.0  Palestinian     Neve Daniel                 Bethlehem
# ...     ...          ...             ...                       ...
# 10340  18.0  Palestinian  East Jerusalem            East Jerusalem
# 10341  45.0  Palestinian  East Jerusalem            East Jerusalem
# 10342  22.0  Palestinian  East Jerusalem            East Jerusalem
# 10343  25.0  Palestinian  East Jerusalem            East Jerusalem
# 10344  35.0  Palestinian  East Jerusalem            East Jerusalem
#
#       Event location - Region Gender                Killed By  \
# 0                   West Bank      M  Israeli security forces
# ...

# %%
Palestinians_killed_year_month=Palestinians_killed.groupby(["Year","Month"],as_index=False).sum().drop(columns=['Day','Age'])
Palestinians_killed_year_month
# Out:
#      Year      Month  Count
# 0    2000   December     54
# 1    2000   November    113
# 2    2000    October    106
# 3    2000  September     16
# 4    2001      April     23
# ..    ...        ...    ...
# 246  2021  September     11
# 247  2022      April      4
# 248  2022   February      6
# 249  2022    January      5
# 250  2022     March      14
#
# [251 rows x 3 columns]

# %%
Palestinians_killed_year=Palestinians_killed.groupby(["Year"],as_index=False).sum().drop(columns=['Day','Age'])
Palestinians_killed_year
# Out:
#     Year  Count
# 0   2000    289
# 1   2001    474
# 2   2002   1044
# 3   2003    592
# 4   2004    831
# 5   2005    197
# 6   2006    665
# 7   2007    385
# 8   2008    889
# 9   2009   1038
# 10  2010     84
# 11  2011    120
# 12  2012    255
# 13  2013     38
# 14  2014   2274
# 15  2015    168
# 16  2016    112
# 17  2017     75
# 18  2018    299
# 19  2019    138
# 20  2020     28
# 21  2021    321
# 22  2022     29

# %%
Palestinians_killed.to_csv('D:\\extrnal hard\\ITI\Data visual\\data_visual_project\\data\\Palestinians_killed.csv',index=False)

# %%
Palestinians_killed_year_month.to_csv('D:\\extrnal hard\\ITI\Data visual\\data_visual_project\\data\\Palestinians_killed_year_month.csv',index=False)

# %%
Palestinians_killed_year.to_csv('D:\\extrnal hard\\ITI\Data visual\\data_visual_project\\data\\Palestinians_killed_year.csv',index=False)

# %%
pd.read_csv('D:\\extrnal hard\\ITI\Data visual\\data_visual_project\\data\\Palestinians_killed.csv')
# Out:
#         Age  Citizenship  Event location Event location - District  \
# 0      28.0  Palestinian          'Araba                     Jenin
# 1      24.0  Palestinian          'Araba                     Jenin
# 2      34.0  Palestinian          'Araba                     Jenin
# 3      28.0  Palestinian          Hebron                    Hebron
# 4      30.0  Palestinian     Neve Daniel                 Bethlehem
# ...     ...          ...             ...                       ...
# 10340  18.0  Palestinian  East Jerusalem            East Jerusalem
# 10341  45.0  Palestinian  East Jerusalem            East Jerusalem
# 10342  22.0  Palestinian  East Jerusalem            East Jerusalem
# 10343  25.0  Palestinian  East Jerusalem            East Jerusalem
# 10344  35.0  Palestinian  East Jerusalem            East Jerusalem
#
#       Event location - Region Gender                Killed By  \
# 0                   West Bank      M  Israeli security forces
# ...
